# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import time
import tracemalloc
import linecache
import os
import seaborn as sns

# %%
cell2loc_pcc = pd.read_csv("PCC/cell2loc_pcc.csv", index_col=0)
dwls_pcc = pd.read_csv("PCC/dwls_pcc.csv", index_col=0)
ground_pcc = pd.read_csv("PCC/ground_pcc.csv", index_col=0)
spotlight_pcc = pd.read_csv("PCC/spotlight_pcc.csv", index_col=0)

cell2loc_spearman = pd.read_csv("SPEARMANR/cell2loc_spearmanr.csv", index_col=0)
dwls_spearman = pd.read_csv("SPEARMANR/dwls_spearmanr.csv", index_col=0)
ground_spearman = pd.read_csv("SPEARMANR/ground_spearmanr.csv", index_col=0)
spotlight_spearman = pd.read_csv("SPEARMANR/spotlight_spearmanr.csv", index_col=0)

# %%
cell2loc_pcc
# Out:
#             1700022A21RIK  1700025G04RIK  4933401B06RIK  5830417I10RIK  \
# olig             0.090853      -0.004159      -0.073345       0.045709
# astrocytes       0.022923      -0.070071       0.059794       0.075509
# eNeuron          0.001365       0.043724       0.039243       0.000246
# endo_mural      -0.061372       0.058868      -0.010662      -0.012873
# iNeuron         -0.012197      -0.085482       0.034635      -0.039935
# microglia       -0.016227       0.043316      -0.085136      -0.064893
#
#             9330102E08RIK  9430018G01RIK  9430083A17RIK     AANAT     AASDH  \
# olig             0.086056      -0.021419      -0.008637  0.013857 -0.061400
# astrocytes      -0.016974       0.063380       0.071173 -0.004085  0.045153
# eNeuron         -0.075085       0.024983       0.004693 -0.030158  0.020130
# endo_mural       0.042206      -0.045615      -0.035031 -0.027707 -0.085298
# iNeuron          0.016268      -0.059223      -0.002804  0.016485  0.066952
# ...

# %%
#Difference Matrix
diff_matrix = np.abs(cell2loc_pcc - cell2loc_spearman)


#Heatmaps
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.heatmap(cell2loc_pcc, annot=True)
plt.title('Pearson Correlation')
plt.subplot(1, 2, 2)
sns.heatmap(cell2loc_spearman, annot=True)
plt.title('Spearman Correlation')
plt.show()

#Difference Heatmap
plt.figure(figsize=(6, 6))
sns.heatmap(diff_matrix, annot=True)
plt.title('Absolute Difference Matrix')
plt.show()

# %%
#Difference Heatmap
plt.figure(figsize=(10, 10))
ax = sns.heatmap(diff_matrix, xticklabels=False)
# Rotate y-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right")

plt.title('Cell2loc Absolute Difference Matrix')
plt.show()

# %%
diff_matrix = np.abs(dwls_pcc - dwls_spearman)
#Difference Heatmap
plt.figure(figsize=(10, 10))
ax = sns.heatmap(diff_matrix, xticklabels=False)
# Rotate y-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right")

plt.title('DWLS Absolute Difference Matrix')
plt.show()

# %%
diff_matrix = np.abs(spotlight_pcc - spotlight_spearman)
#Difference Heatmap
plt.figure(figsize=(10, 10))
ax = sns.heatmap(diff_matrix, xticklabels=False)
# Rotate y-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right")

plt.title('Spotlight Absolute Difference Matrix')
plt.show()

# %%
diff_matrix = np.abs(ground_pcc - ground_spearman)
#Difference Heatmap
plt.figure(figsize=(10, 10))
ax = sns.heatmap(diff_matrix, xticklabels=False)
# Rotate y-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right")

plt.title('GroundTruth Absolute Difference Matrix')
plt.show()
